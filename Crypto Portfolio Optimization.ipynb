# %% [markdown]
# # Import Data

# %%
import numpy as np
import pandas as pd
from pandas_datareader import data
import matplotlib.pyplot as plt
import yfinance as yf
import seaborn as sns


# %matplotlib inline

# %% [markdown]
# # Extracting Data

# %%
BTC_data = yf.Ticker("BTC-USD")
df_BTC = BTC_data.history(start = '2010-1-1', end='2022-1-1')
df_BTC.dropna()
df_BTC
# Out:
#                     Open          High           Low         Close  \
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2021-04-18  60701.886719  61057.457031  52829.535156  56216.183594
# 2021-04-19  56191.585938  57520.054688  54368.593750  55724.265625
# 2021-04-20  55681.792969  57062.148438  53448.046875  56473.031250
# 2021-04-21  56471.128906  56757.972656  53695.468750  53906.089844
# 2021-04-22  53878.425781  54799.714844  52777.246094  53573.843750
#
#                  Volume  Dividends  Stock Splits
# Date
# 2014-09-17     21056800          0             0
# 2014-09-18     34483200          0             0
# ...

# %%
ETH_data = yf.Ticker("ETH-USD")
df_ETH = ETH_data.history(start = '2010-1-1', end='2022-1-1')
df_ETH.dropna()
df_ETH
# Out:
#                    Open         High          Low        Close       Volume  \
# Date
# 2015-08-07     2.831620     3.536610     2.521120     2.772120       164329
# 2015-08-08     2.793760     2.798810     0.714725     0.753325       674188
# 2015-08-09     0.706136     0.879810     0.629191     0.701897       532170
# 2015-08-10     0.713989     0.729854     0.636546     0.708448       405283
# 2015-08-11     0.708087     1.131410     0.663235     1.067860      1463100
# ...                 ...          ...          ...          ...          ...
# 2021-04-18  2346.452393  2365.460449  2011.766846  2237.136963  50696368718
# 2021-04-19  2238.032715  2276.776855  2086.688721  2166.188721  34060654971
# 2021-04-20  2161.939453  2345.834961  2060.143799  2330.210938  39433483315
# 2021-04-21  2331.160156  2467.200684  2238.366943  2364.751709  38899067643
# 2021-04-22  2432.654541  2492.266846  2326.844727  2449.510254  44207280128
#
#             Dividends  Stock Splits
# Date
# ...

# %%
BNB_data = yf.Ticker("BNB-USD")
df_BNB = BNB_data.history(start = '2010-1-1', end='2022-1-1')
df_BNB.dropna()
df_BNB
# Out:
#                   Open        High         Low       Close      Volume  \
# Date
# 2017-07-25    0.115203    0.115841    0.101531    0.105870      145269
# 2017-07-26    0.105893    0.109013    0.099266    0.105138      200395
# 2017-07-27    0.105108    0.108479    0.100888    0.107737      344499
# 2017-07-28    0.107632    0.109019    0.101473    0.104067      342568
# 2017-07-29    0.104782    0.111264    0.101108    0.107811      340218
# ...                ...         ...         ...         ...         ...
# 2021-04-18  520.590271  526.058777  429.052887  481.034241  6711806048
# 2021-04-19  481.396698  539.711243  469.152161  505.092926  7141301320
# 2021-04-20  503.795166  588.064819  475.590393  587.029114  9330924061
# 2021-04-21  586.901184  612.687073  537.349365  546.023560  8456300946
# 2021-04-22  544.512268  568.134766  535.349915  545.663086  7616423936
#
#             Dividends  Stock Splits
# Date
# 2017-07-25          0             0
# ...

# %%
XRP_data = yf.Ticker("XRP-USD")
df_XRP = XRP_data.history(start = '2010-1-1', end='2022-1-1')
df_XRP.dropna()
df_XRP
# Out:
#                 Open      High       Low     Close       Volume  Dividends  \
# Date
# 2014-09-17  0.005123  0.005803  0.005123  0.005399      1281960          0
# 2014-09-18  0.005398  0.005521  0.005091  0.005135       491147          0
# 2014-09-19  0.005134  0.005167  0.004873  0.004942       407109          0
# 2014-09-20  0.004942  0.004954  0.004736  0.004772       322621          0
# 2014-09-21  0.004768  0.004791  0.004540  0.004570       309571          0
# ...              ...       ...       ...       ...          ...        ...
# 2021-04-18  1.559104  1.578567  1.174665  1.405998  22933939682          0
# 2021-04-19  1.409457  1.530381  1.258307  1.315044  17637508685          0
# 2021-04-20  1.309951  1.445636  1.186228  1.383299  15562116615          0
# 2021-04-21  1.386157  1.458540  1.282823  1.296498  12545052977          0
# 2021-04-22  1.332722  1.337220  1.268021  1.278418  12152860672          0
#
#             Stock Splits
# Date
# 2014-09-17             0
# ...

# %%
LTC_data = yf.Ticker("LTC-USD")
df_LTC = LTC_data.history(start = '2010-1-1', end='2022-1-1')
df_LTC.dropna()
df_LTC
# Out:
#                   Open        High         Low       Close       Volume  \
# Date
# 2014-09-17    5.085890    5.170770    4.965950    5.058550      3071840
# 2014-09-18    5.065430    5.065430    4.579960    4.685230      4569260
# 2014-09-19    4.687290    4.755820    4.254350    4.327770      3917450
# 2014-09-20    4.329200    4.616080    4.202190    4.286440      5490660
# 2014-09-21    4.263070    4.300130    4.154990    4.245920      2931220
# ...                ...         ...         ...         ...          ...
# 2021-04-18  304.647034  307.304260  238.337418  273.098816  13129808269
# 2021-04-19  273.645142  281.352539  251.514481  261.919220   9384818110
# 2021-04-20  261.280304  272.592438  235.673401  260.941345   9446199109
# 2021-04-21  261.067902  276.310242  251.684235  258.805603   7698253801
# 2021-04-22  262.850555  268.496887  253.337433  262.502075   7680966656
#
#             Dividends  Stock Splits
# Date
# 2014-09-17          0             0
# ...

# %%
Treasury10Y = yf.Ticker("^TNX")
risk_free = Treasury10Y.history(start="2021-4-20", end="2022-1-1")
risk_free
# Out:
#              Open   High    Low  Close  Volume  Dividends  Stock Splits
# Date
# 2021-04-19  1.587  1.615  1.580  1.601       0          0             0
# 2021-04-20  1.594  1.612  1.557  1.562       0          0             0
# 2021-04-21  1.568  1.584  1.554  1.564       0          0             0

# %% [markdown]
# # Resampling Data

# %%
BTC_Close_df = df_BTC.Close
BTC_Close_df
# Out:
# Date
# 2014-09-17      457.334015
# 2014-09-18      424.440002
# 2014-09-19      394.795990
# 2014-09-20      408.903992
# 2014-09-21      398.821014
#                   ...
# 2021-04-18    56216.183594
# 2021-04-19    55724.265625
# 2021-04-20    56473.031250
# 2021-04-21    53906.089844
# 2021-04-22    53573.843750
# Name: Close, Length: 2406, dtype: float64

# %%
ETH_Close_df = df_ETH.Close
ETH_Close_df
# Out:
# Date
# 2015-08-07       2.772120
# 2015-08-08       0.753325
# 2015-08-09       0.701897
# 2015-08-10       0.708448
# 2015-08-11       1.067860
#                  ...
# 2021-04-18    2237.136963
# 2021-04-19    2166.188721
# 2021-04-20    2330.210938
# 2021-04-21    2364.751709
# 2021-04-22    2449.510254
# Name: Close, Length: 2082, dtype: float64

# %%
BNB_Close_df = df_BNB.Close
BNB_Close_df
# Out:
# Date
# 2017-07-25      0.105870
# 2017-07-26      0.105138
# 2017-07-27      0.107737
# 2017-07-28      0.104067
# 2017-07-29      0.107811
#                  ...
# 2021-04-18    481.034241
# 2021-04-19    505.092926
# 2021-04-20    587.029114
# 2021-04-21    546.023560
# 2021-04-22    545.663086
# Name: Close, Length: 1364, dtype: float64

# %%
XRP_Close_df = df_XRP.Close
XRP_Close_df
# Out:
# Date
# 2014-09-17    0.005399
# 2014-09-18    0.005135
# 2014-09-19    0.004942
# 2014-09-20    0.004772
# 2014-09-21    0.004570
#                 ...
# 2021-04-18    1.405998
# 2021-04-19    1.315044
# 2021-04-20    1.383299
# 2021-04-21    1.296498
# 2021-04-22    1.278418
# Name: Close, Length: 2406, dtype: float64

# %%
LTC_Close_df = df_LTC.Close
LTC_Close_df
# Out:
# Date
# 2014-09-17      5.058550
# 2014-09-18      4.685230
# 2014-09-19      4.327770
# 2014-09-20      4.286440
# 2014-09-21      4.245920
#                  ...
# 2021-04-18    273.098816
# 2021-04-19    261.919220
# 2021-04-20    260.941345
# 2021-04-21    258.805603
# 2021-04-22    262.502075
# Name: Close, Length: 2406, dtype: float64

# %% [markdown]
# # Combine Data

# %%
crypto_df = pd.concat([
    BTC_Close_df ,
    ETH_Close_df ,
    BNB_Close_df , 
    XRP_Close_df , 
    LTC_Close_df
],axis="columns",join="inner")
crypto_df
# Out:
#                    Close        Close       Close     Close       Close
# Date
# 2017-07-25   2576.479980   206.710007    0.105870  0.178104   42.241299
# 2017-07-26   2529.449951   203.953003    0.105138  0.173822   42.229698
# 2017-07-27   2671.780029   204.317993    0.107737  0.173457   42.139801
# 2017-07-28   2809.010010   193.123001    0.104067  0.165937   40.614601
# 2017-07-29   2726.449951   205.789001    0.107811  0.169871   41.115501
# ...                  ...          ...         ...       ...         ...
# 2021-04-18  56216.183594  2237.136963  481.034241  1.405998  273.098816
# 2021-04-19  55724.265625  2166.188721  505.092926  1.315044  261.919220
# 2021-04-20  56473.031250  2330.210938  587.029114  1.383299  260.941345
# 2021-04-21  53906.089844  2364.751709  546.023560  1.296498  258.805603
# 2021-04-22  53573.843750  2449.510254  545.663086  1.278418  262.502075
#
# [1364 rows x 5 columns]

# %%
crypto_df.columns = ['BTC-USD', 'ETH-USD', 'BNB-USD', 'XRP-USD', 'LTC-USD']
crypto_df
# Out:
#                  BTC-USD      ETH-USD     BNB-USD   XRP-USD     LTC-USD
# Date
# 2017-07-25   2576.479980   206.710007    0.105870  0.178104   42.241299
# 2017-07-26   2529.449951   203.953003    0.105138  0.173822   42.229698
# 2017-07-27   2671.780029   204.317993    0.107737  0.173457   42.139801
# 2017-07-28   2809.010010   193.123001    0.104067  0.165937   40.614601
# 2017-07-29   2726.449951   205.789001    0.107811  0.169871   41.115501
# ...                  ...          ...         ...       ...         ...
# 2021-04-18  56216.183594  2237.136963  481.034241  1.405998  273.098816
# 2021-04-19  55724.265625  2166.188721  505.092926  1.315044  261.919220
# 2021-04-20  56473.031250  2330.210938  587.029114  1.383299  260.941345
# 2021-04-21  53906.089844  2364.751709  546.023560  1.296498  258.805603
# 2021-04-22  53573.843750  2449.510254  545.663086  1.278418  262.502075
#
# [1364 rows x 5 columns]

# %% [markdown]
# # Run Quantitative Analysis

# %%
#Plot Daily Price Action of Cryptos

crypto_df['BTC-USD'].plot(figsize=(15,9), label="BTC", title="Crypto Price Daily Movement")
crypto_df['ETH-USD'].plot(label="ETH")
crypto_df['XRP-USD'].plot(label="XRP")
crypto_df['BNB-USD'].plot(label="BNB")
crypto_df['LTC-USD'].plot(label="LTC")

plt.legend()
plt.show;

# %%
#Normalise data

#Calculate daily returns
crypto_returns = crypto_df.pct_change().apply(lambda x: np.log(1+x))
crypto_returns.dropna()
crypto_returns
# Out:
#              BTC-USD   ETH-USD   BNB-USD   XRP-USD   LTC-USD
# Date
# 2017-07-25       NaN       NaN       NaN       NaN       NaN
# 2017-07-26 -0.018422 -0.013427 -0.006938 -0.024336 -0.000275
# 2017-07-27  0.054743  0.001788  0.024419 -0.002102 -0.002131
# 2017-07-28  0.050087 -0.056350 -0.034658 -0.044321 -0.036865
# 2017-07-29 -0.029832  0.063524  0.035345  0.023431  0.012258
# ...              ...       ...       ...       ...       ...
# 2021-04-18 -0.076472 -0.047044 -0.078691 -0.103974 -0.109691
# 2021-04-19 -0.008789 -0.032228  0.048804 -0.066877 -0.041798
# 2021-04-20  0.013348  0.072990  0.150332  0.050601 -0.003740
# 2021-04-21 -0.046520  0.014714 -0.072412 -0.064804 -0.008218
# 2021-04-22 -0.006182  0.035215 -0.000660 -0.014043  0.014182
#
# [1364 rows x 5 columns]

# %%
crypto_returns.plot(figsize=(30,20))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
crypto_returns.describe()
# Out:
#            BTC-USD      ETH-USD      BNB-USD      XRP-USD      LTC-USD
# count  1363.000000  1363.000000  1363.000000  1363.000000  1363.000000
# mean      0.002226     0.001814     0.006271     0.001446     0.001340
# std       0.042408     0.052340     0.074153     0.066838     0.057411
# min      -0.464730    -0.550732    -0.543084    -0.550503    -0.449062
# 25%      -0.015019    -0.020267    -0.024274    -0.022843    -0.026038
# 50%       0.001930     0.001334     0.001277    -0.001281     0.000040
# 75%       0.019931     0.027126     0.032257     0.020492     0.026683
# max       0.225119     0.234741     0.675174     0.606885     0.389321

# %%
#Calculate cumulative returns of the crypto 
crypto_cump_returns = np.cumprod(1 + crypto_returns)
crypto_cump_returns
# Out:
#              BTC-USD   ETH-USD     BNB-USD   XRP-USD   LTC-USD
# Date
# 2017-07-25       NaN       NaN         NaN       NaN       NaN
# 2017-07-26  0.981578  0.986573    0.993062  0.975664  0.999725
# 2017-07-27  1.035312  0.988337    1.017312  0.973613  0.997595
# 2017-07-28  1.087168  0.932644    0.982054  0.930461  0.960819
# 2017-07-29  1.054736  0.991889    1.016764  0.952263  0.972596
# ...              ...       ...         ...       ...       ...
# 2021-04-18  6.079217  1.491651  114.942197  0.386170  0.660737
# 2021-04-19  6.025787  1.443579  120.551832  0.360344  0.633120
# 2021-04-20  6.106216  1.548945  138.674629  0.378578  0.630751
# 2021-04-21  5.822156  1.571736  128.632881  0.354044  0.625568
# 2021-04-22  5.786161  1.627085  128.547932  0.349072  0.634439
#
# [1364 rows x 5 columns]

# %%
crypto_cump_returns.plot(figsize=(30,20))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Calculate means
crypto_means = crypto_returns.mean()
crypto_means
# Out:
# BTC-USD    0.002226
# ETH-USD    0.001814
# BNB-USD    0.006271
# XRP-USD    0.001446
# LTC-USD    0.001340
# dtype: float64

# %%
#Calculate Standard Deviation
crypto_std = crypto_returns.std()
crypto_std
# Out:
# BTC-USD    0.042408
# ETH-USD    0.052340
# BNB-USD    0.074153
# XRP-USD    0.066838
# LTC-USD    0.057411
# dtype: float64

# %%
#Annual standard deviation
annual_std = crypto_df.pct_change().apply(lambda x: np.log(1+x)).std().apply(lambda x: x*np.sqrt(365))
annual_std
# Out:
# BTC-USD    0.810195
# ETH-USD    0.999951
# BNB-USD    1.416690
# XRP-USD    1.276932
# LTC-USD    1.096836
# dtype: float64

# %%
#Calculate Covariance Matrix
crypto_cov_matrix = crypto_returns.cov()
crypto_cov_matrix
# Out:
#           BTC-USD   ETH-USD   BNB-USD   XRP-USD   LTC-USD
# BTC-USD  0.001798  0.001672  0.001792  0.001365  0.001780
# ETH-USD  0.001672  0.002739  0.002129  0.002127  0.002421
# BNB-USD  0.001792  0.002129  0.005499  0.001847  0.002238
# XRP-USD  0.001365  0.002127  0.001847  0.004467  0.002177
# LTC-USD  0.001780  0.002421  0.002238  0.002177  0.003296

# %%
# Plot the correlation heatmap
crypto_corr = crypto_returns.corr()
ax = sns.heatmap(
    crypto_corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %% [markdown]
# # Applying Markowitz Portfolio Theory (MPT) with Efficient Frontier

# %%
# Creating a table for visualising returns and volatility of assets
crypto_assets = pd.concat([crypto_means, crypto_std], axis=1) 
crypto_assets.columns = ['Returns', 'Volatility']
crypto_assets
# Out:
#           Returns  Volatility
# BTC-USD  0.002226    0.042408
# ETH-USD  0.001814    0.052340
# BNB-USD  0.006271    0.074153
# XRP-USD  0.001446    0.066838
# LTC-USD  0.001340    0.057411

# %%
#the loop considers different weights for assets and calculates the return and volatility of that particular portfolio combination.

p_ret = [] # Define an empty array for portfolio returns
p_vol = [] # Define an empty array for portfolio volatility
p_weights = [] # Define an empty array for asset weights

num_assets = len(crypto_df.columns)
num_portfolios = 10000

# %%
for portfolio in range(num_portfolios):
    weights = np.random.random(num_assets)
    weights = weights/np.sum(weights)
    p_weights.append(weights)
    crypto_returns = np.dot(weights, crypto_means) # Returns are the product of individual expected returns of asset and its 
                                      # weights 
    p_ret.append(crypto_returns)
    var = crypto_cov_matrix.mul(weights, axis=0).mul(weights, axis=1).sum().sum()# Portfolio Variance
    crypto_std = np.sqrt(var) # Daily standard deviation
    annual_std = crypto_std*np.sqrt(365) # Annual standard deviation = volatility
    p_vol.append(annual_std)

# %%
data = {'Returns':p_ret, 'Volatility':p_vol}

for counter, symbol in enumerate(crypto_df.columns.tolist()):
    #print(counter, symbol)
    data[symbol+' weight'] = [w[counter] for w in p_weights]

# %%
crypto_portfolios = pd.DataFrame(data)
crypto_portfolios.head(50) # Dataframe of the 10000 portfolios created
# Out:
#      Returns  Volatility  BTC-USD weight  ETH-USD weight  BNB-USD weight  \
# 0   0.001603    0.948527        0.111724        0.217887        0.007390
# 1   0.003043    0.925165        0.216355        0.178290        0.285431
# 2   0.002472    0.892360        0.276582        0.122960        0.163416
# 3   0.002115    0.910764        0.173738        0.260693        0.096034
# 4   0.002393    0.868489        0.330300        0.263784        0.125959
# 5   0.003319    0.978995        0.160321        0.054479        0.365093
# 6   0.002590    0.918406        0.181518        0.187746        0.197671
# 7   0.003148    0.936668        0.242779        0.158735        0.306633
# 8   0.001697    1.004730        0.140979        0.177017        0.017692
# 9   0.002651    0.923867        0.158782        0.300487        0.206420
# 10  0.001946    0.933205        0.138201        0.430967        0.056176
# 11  0.002162    0.905084        0.196151        0.251893        0.103679
# ...

# %%
# Plot efficient frontier
crypto_portfolios.plot.scatter(x='Volatility', y='Returns', marker='o', s=10, alpha=0.3, grid=True, figsize=[20,20])
# Out:
# <AxesSubplot:xlabel='Volatility', ylabel='Returns'>

# %%
#How to read the Efficient Frontier?
# Each point on the line (left edge) represents an optimal portfolio of stocks that maximises the returns for any given level of risk.
# The point (portfolios) in the interior are sub-optimal for a given risk level. 
# For every interior point, there is another that offers higher returns for the same risk.
# On this graph, you can also see the combination of weights that will give you all possible combinations:
#Minimum volatility (left most point); and Maximum returns (top most point); And everything in between.

# %%
min_vol_port = crypto_portfolios.iloc[crypto_portfolios['Volatility'].idxmin()]
# idxmin() gives us the minimum value in the column specified.                               
min_vol_port
# Out:
# Returns           0.002135
# Volatility        0.802642
# BTC-USD weight    0.746819
# ETH-USD weight    0.110391
# BNB-USD weight    0.014113
# XRP-USD weight    0.106740
# LTC-USD weight    0.021937
# Name: 3644, dtype: float64

# %%
# plotting the minimum volatility portfolio
plt.subplots(figsize=[30,30])
plt.scatter(crypto_portfolios['Volatility'], crypto_portfolios['Returns'],marker='o', s=10, alpha=0.3)
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=500)

#The red star denotes the most efficient portfolio with minimum volatility.

# %%
# An optimal risky portfolio can be considered as one that has highest Sharpe ratio.
# Finding the optimal portfolio

rf = 1.564 / 100 # risk factor
optimal_risky_port = crypto_portfolios.iloc[((crypto_portfolios['Returns']-rf)/crypto_portfolios['Volatility']).idxmax()]
optimal_risky_port
# Out:
# Returns           0.004935
# Volatility        1.194475
# BTC-USD weight    0.016192
# ETH-USD weight    0.085688
# BNB-USD weight    0.717282
# XRP-USD weight    0.023508
# LTC-USD weight    0.157331
# Name: 5358, dtype: float64

# %%
# Plotting optimal portfolio

plt.subplots(figsize=(20, 20))
plt.scatter(crypto_portfolios['Volatility'], crypto_portfolios['Returns'],marker='o', s=10, alpha=0.3)
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=500)
plt.scatter(optimal_risky_port[1], optimal_risky_port[0], color='g', marker='*', s=500)

#The green star represents the optimal risky portfolio.

# %% [markdown]
# # Calculating portfolio allocation of the portfolio

# %%
#Determine the investment amount
initial_investment = 30000

# %%
#Determine the weights for minimum variance portfolio
crypto_MVP_weights = [min_vol_port['BTC-USD weight'],min_vol_port['ETH-USD weight'],min_vol_port['BNB-USD weight'],min_vol_port['XRP-USD weight'],min_vol_port['LTC-USD weight']]
crypto_MVP_weights
# Out:
# [0.7468186061792665,
#  0.11039126070464932,
#  0.014113385670656758,
#  0.10673985598681561,
#  0.021936891458611735]

# %%
#Determine the weights for risky portfolio
crypto_risky_weights = [optimal_risky_port['BTC-USD weight'],optimal_risky_port['ETH-USD weight'],optimal_risky_port['BNB-USD weight'],optimal_risky_port['XRP-USD weight'],optimal_risky_port['LTC-USD weight']]
crypto_risky_weights
# Out:
# [0.01619219872649794,
#  0.08568766476165643,
#  0.7172815182276493,
#  0.0235078049259381,
#  0.15733081335825824]

# %%
#Crypto MV portfolio weight
btc_investment_amount = crypto_MVP_weights[0] * initial_investment
eth_investment_amount = crypto_MVP_weights[1] * initial_investment
bnb_investment_amount = crypto_MVP_weights[2] * initial_investment
xrp_investment_amount = crypto_MVP_weights[3] * initial_investment
ltc_investment_amount = crypto_MVP_weights[4] * initial_investment

print (f"The current investment amount of your BTC is ${btc_investment_amount:0.2f}")
print (f"The current investment amount of your ETH is ${eth_investment_amount:0.2f}")
print (f"The current investment amount of your BNB is ${bnb_investment_amount:0.2f}")
print (f"The current investment amount of your XRP is ${xrp_investment_amount:0.2f}")
print (f"The current investment amount of your LTC is ${ltc_investment_amount:0.2f}")
# Out:
# The current investment amount of your BTC is $22404.56
# The current investment amount of your ETH is $3311.74
# The current investment amount of your BNB is $423.40
# The current investment amount of your XRP is $3202.20
# The current investment amount of your LTC is $658.11

# %%
#Crypto risky portfolio weight
btc_investment_amount = crypto_risky_weights[0] * initial_investment
eth_investment_amount = crypto_risky_weights[1] * initial_investment
bnb_investment_amount = crypto_risky_weights[2] * initial_investment
xrp_investment_amount = crypto_risky_weights[3] * initial_investment
ltc_investment_amount = crypto_risky_weights[4] * initial_investment

print (f"The current investment amount of your BTC is ${btc_investment_amount:0.2f}")
print (f"The current investment amount of your ETH is ${eth_investment_amount:0.2f}")
print (f"The current investment amount of your BNB is ${bnb_investment_amount:0.2f}")
print (f"The current investment amount of your XRP is ${xrp_investment_amount:0.2f}")
print (f"The current investment amount of your LTC is ${ltc_investment_amount:0.2f}")
# Out:
# The current investment amount of your BTC is $485.77
# The current investment amount of your ETH is $2570.63
# The current investment amount of your BNB is $21518.45
# The current investment amount of your XRP is $705.23
# The current investment amount of your LTC is $4719.92

# %% [markdown]
# # Calculating Value at Risk (VaR) of a crypto portfolio

# %%
#Convert Lists to DataFrames
data_MVP_weights = [ ['BTC-USD weight', min_vol_port['BTC-USD weight']] ,
             ['ETH-USD weight', min_vol_port['ETH-USD weight']] ,
             ['BNB-USD weight', min_vol_port['BNB-USD weight']] ,
             ['XRP-USD weight', min_vol_port['XRP-USD weight']] ,   
             ['LTC-USD weight', min_vol_port['LTC-USD weight']] ,   
               ]
df_MVP_weights = pd.DataFrame(data_MVP_weights,columns=('MVP_Allocation','MVP_weights')).set_index('MVP_Allocation')
df_MVP_weights
# Out:
#                 MVP_weights
# MVP_Allocation
# BTC-USD weight     0.746819
# ETH-USD weight     0.110391
# BNB-USD weight     0.014113
# XRP-USD weight     0.106740
# LTC-USD weight     0.021937

# %%
data_risky_weights = [ ['BTC-USD weight', optimal_risky_port['BTC-USD weight']] ,
             ['ETH-USD weight', optimal_risky_port['ETH-USD weight']] ,
             ['BNB-USD weight', optimal_risky_port['BNB-USD weight']] ,
             ['XRP-USD weight', optimal_risky_port['XRP-USD weight']] ,   
             ['LTC-USD weight', optimal_risky_port['LTC-USD weight']] ,   
               ]
df_risky_weights = pd.DataFrame(data_risky_weights,columns=('MVP_Allocation','MVP_weights')).set_index('MVP_Allocation')
df_risky_weights
# Out:
#                 MVP_weights
# MVP_Allocation
# BTC-USD weight     0.016192
# ETH-USD weight     0.085688
# BNB-USD weight     0.717282
# XRP-USD weight     0.023508
# LTC-USD weight     0.157331
